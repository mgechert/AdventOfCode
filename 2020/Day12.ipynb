# %% [markdown]
# ## -- [Day 12: Rain Risk](https://adventofcode.com/2020/day/12) --
#
#
#     Action N means to move north by the given value.
#     Action S means to move south by the given value.
#     Action E means to move east by the given value.
#     Action W means to move west by the given value.
#     Action L means to turn left the given number of degrees.
#     Action R means to turn right the given number of degrees.
#     Action F means to move forward by the given value in the direction the ship is currently facing.

# %%
from enum import Enum

INPUT_FILE = 'input_d12.txt'
EXAMPLE_FILE = 'input2_d12.txt'

class Direction(Enum):
    N = 0
    E = 90
    S = 180
    W = 270
    
    def rotate(self, right_left, degree):
        '''
        Returns the new direction after rotating a set number of degrees
        :param right_left: either 'R' for clockwise (the default) turn or 'L' for counter-clockwise
        :param degree: The number degrees to turn
        '''
        if degree % 90 != 0:
            raise IllegalArgument('Can only turn in multiples of 90 degrees')
        if right_left == 'L':
            degree = -degree
        new_dir = (self.value + degree) % 360
        return Direction(new_dir)

class Ship:
    def __init__(self, input_file=INPUT_FILE):
        # Initial direction is given as EAST
        self.orientation = Direction.E
        self.east_west = 0
        self.north_south = 0
        self.load_directions(input_file)
    
    def process_action(self, command, param):
        '''
        Processes an individual action
        :param command: One of [N, S, E, W, L, R, F]
        :param param: The parameter--units to move when [N,S,E,W,F], or degrees with [R,L]
        '''
        if command in ['R','L']:
            self.orientation = self.orientation.rotate(command, param)
            print(f'Rotating. Now facing {self.orientation}')
        elif command == 'F':
            self.move(self.orientation, param)
        elif command in ['N','S','E','W']:
            self.move(Direction[command], param)
        else:
            raise IllegalArgument('Unrecognized command')
    
    def move(self, direction, distance):
        '''
        For a move in a given direction, updates state accordingly
        :param direction: a Direction enum
        :param distance: the integer distance to move
        '''
        if direction == Direction.N:
            self.north_south += distance
        elif direction == Direction.S:
            self.north_south -= distance
        elif direction == Direction.E:
            self.east_west += distance
        elif direction == Direction.W:
            self.east_west -= distance
        else:
            raise IllegalArgument('Illegal direction')
            
        print(f'Move {direction} by {distance}, now at {self.north_south}, {self.east_west}')
        
    def manhattan_dist(self):
        '''
        Part 1 solution - returns the Manhattan distance from the origin
        '''
        return abs(self.north_south) + abs(self.east_west)
        
    def load_directions(self, input_file):
        with open(input_file) as fh:
            for line in fh.readlines():
                self.process_action(line[0], int(line[1:]))

# %%
ex = Ship(EXAMPLE_FILE)
ex.manhattan_dist()
# Out:
# Move Direction.E by 10, now at 0, 10
# Move Direction.N by 3, now at 3, 10
# Move Direction.E by 7, now at 3, 17
# Rotating. Now facing Direction.S
# Move Direction.S by 11, now at -8, 17
# 25

# %%
# Part 1 solution
ship = Ship()
ship.manhattan_dist()
# Out:
# Move Direction.E by 5, now at 0, 5
# Rotating. Now facing Direction.S
# Move Direction.E by 5, now at 0, 10
# Rotating. Now facing Direction.E
# Move Direction.E by 80, now at 0, 90
# Rotating. Now facing Direction.N
# Move Direction.E by 3, now at 0, 93
# Move Direction.N by 5, now at 5, 93
# Move Direction.N by 10, now at 15, 93
# Move Direction.S by 2, now at 13, 93
# Move Direction.W by 1, now at 13, 92
# Move Direction.N by 98, now at 111, 92
# Rotating. Now facing Direction.S
# Move Direction.W by 1, now at 111, 91
# Move Direction.S by 55, now at 56, 91
# Rotating. Now facing Direction.E
# Move Direction.E by 73, now at 56, 164
# Move Direction.N by 1, now at 57, 164
# Move Direction.E by 3, now at 57, 167
# Move Direction.S by 2, now at 55, 167
# Move Direction.E by 5, now at 55, 172
# Rotating. Now facing Direction.S
# Move Direction.E by 2, now at 55, 174
# Move Direction.S by 4, now at 51, 174
# Move Direction.S by 34, now at 17, 174
# Rotating. Now facing Direction.W
# Move Direction.W by 2, now at 17, 172
# Rotating. Now facing Direction.S
# Move Direction.W by 4, now at 17, 168
# Move Direction.S by 92, now at -75, 168
# Rotating. Now facing Direction.W
# Move Direction.W by 4, now at -75, 164
# Move Direction.N by 5, now at -70, 164
# Rotating. Now facing Direction.N
# Move Direction.N by 73, now at 3, 164
# Move Direction.S by 4, now at -1, 164
# Move Direction.W by 3, now at -1, 161
# Move Direction.N by 4, now at 3, 161
# Rotating. Now facing Direction.E
# Move Direction.S by 3, now at 0, 161
# Move Direction.W by 3, now at 0, 158
# Move Direction.N by 4, now at 4, 158
# Move Direction.E by 30, now at 4, 188
# Move Direction.S by 5, now at -1, 188
# Move Direction.E by 4, now at -1, 192
# Rotating. Now facing Direction.S
# Move Direction.W by 5, now at -1, 187
# Rotating. Now facing Direction.W
# Move Direction.S by 3, now at -4, 187
# Move Direction.E by 5, now at -4, 192
# Rotating. Now facing Direction.E
# Move Direction.E by 2, now at -4, 194
# Move Direction.S by 4, now at -8, 194
# Move Direction.E by 4, now at -8, 198
# Move Direction.S by 2, now at -10, 198
# Move Direction.W by 3, now at -10, 195
# Move Direction.E by 19, now at -10, 214
# Move Direction.N by 2, now at -8, 214
# Move Direction.E by 53, now at -8, 267
# Rotating. Now facing Direction.S
# Move Direction.W by 4, now at -8, 263
# Rotating. Now facing Direction.W
# Move Direction.N by 3, now at -5, 263
# Move Direction.W by 5, now at -5, 258
# Rotating. Now facing Direction.N
# Move Direction.W by 4, now at -5, 254
# Move Direction.N by 68, now at 63, 254
# Move Direction.W by 4, now at 63, 250
# Move Direction.N by 5, now at 68, 250
# Move Direction.N by 26, now at 94, 250
# Move Direction.W by 4, now at 94, 246
# Move Direction.N by 11, now at 105, 246
# Rotating. Now facing Direction.W
# Move Direction.E by 5, now at 105, 251
# Rotating. Now facing Direction.S
# Move Direction.S by 67, now at 38, 251
# Move Direction.W by 3, now at 38, 248
# Move Direction.S by 3, now at 35, 248
# Move Direction.S by 15, now at 20, 248
# Move Direction.E by 4, now at 20, 252
# Move Direction.S by 4, now at 16, 252
# Move Direction.E by 5, now at 16, 257
# Move Direction.S by 1, now at 15, 257
# Move Direction.S by 11, now at 4, 257
# Rotating. Now facing Direction.W
# Move Direction.E by 3, now at 4, 260
# Move Direction.W by 46, now at 4, 214
# Rotating. Now facing Direction.N
# Move Direction.N by 40, now at 44, 214
# Move Direction.E by 3, now at 44, 217
# Rotating. Now facing Direction.E
# Move Direction.E by 35, now at 44, 252
# Rotating. Now facing Direction.W
# Move Direction.E by 3, now at 44, 255
# Move Direction.S by 5, now at 39, 255
# Rotating. Now facing Direction.S
# Move Direction.E by 3, now at 39, 258
# Move Direction.S by 63, now at -24, 258
# Move Direction.E by 4, now at -24, 262
# Move Direction.S by 56, now at -80, 262
# Move Direction.N by 2, now at -78, 262
# Move Direction.E by 1, now at -78, 263
# Rotating. Now facing Direction.W
# Move Direction.N by 3, now at -75, 263
# Move Direction.W by 42, now at -75, 221
# Move Direction.W by 2, now at -75, 219
# Move Direction.S by 4, now at -79, 219
# Move Direction.N by 3, now at -76, 219
# Rotating. Now facing Direction.N
# Move Direction.W by 2, now at -76, 217
# Rotating. Now facing Direction.E
# Move Direction.E by 45, now at -76, 262
# Move Direction.N by 5, now at -71, 262
# Rotating. Now facing Direction.N
# Move Direction.N by 38, now at -33, 262
# Rotating. Now facing Direction.W
# Move Direction.N by 5, now at -28, 262
# Move Direction.E by 4, now at -28, 266
# Rotating. Now facing Direction.N
# Move Direction.N by 2, now at -26, 266
# Rotating. Now facing Direction.E
# Move Direction.S by 4, now at -30, 266
# Rotating. Now facing Direction.S
# Move Direction.N by 3, now at -27, 266
# Move Direction.S by 53, now at -80, 266
# Rotating. Now facing Direction.W
# Move Direction.W by 72, now at -80, 194
# Move Direction.S by 5, now at -85, 194
# Move Direction.E by 3, now at -85, 197
# Move Direction.W by 98, now at -85, 99
# Rotating. Now facing Direction.S
# Move Direction.E by 3, now at -85, 102
# Move Direction.S by 56, now at -141, 102
# Move Direction.S by 2, now at -143, 102
# Move Direction.S by 29, now at -172, 102
# Move Direction.E by 2, now at -172, 104
# Move Direction.W by 3, now at -172, 101
# Rotating. Now facing Direction.N
# Move Direction.S by 4, now at -176, 101
# Move Direction.N by 31, now at -145, 101
# Move Direction.S by 2, now at -147, 101
# Rotating. Now facing Direction.E
# Move Direction.N by 5, now at -142, 101
# Rotating. Now facing Direction.N
# Move Direction.N by 45, now at -97, 101
# Rotating. Now facing Direction.W
# Move Direction.W by 10, now at -97, 91
# Move Direction.N by 5, now at -92, 91
# Rotating. Now facing Direction.N
# Move Direction.E by 5, now at -92, 96
# Move Direction.N by 47, now at -45, 96
# Rotating. Now facing Direction.E
# Move Direction.S by 3, now at -48, 96
# Move Direction.E by 98, now at -48, 194
# Rotating. Now facing Direction.S
# Move Direction.S by 85, now at -133, 194
# Move Direction.E by 1, now at -133, 195
# Rotating. Now facing Direction.E
# Move Direction.S by 4, now at -137, 195
# Rotating. Now facing Direction.W
# Move Direction.N by 4, now at -133, 195
# Rotating. Now facing Direction.S
# Move Direction.W by 5, now at -133, 190
# Rotating. Now facing Direction.W
# Move Direction.E by 4, now at -133, 194
# Rotating. Now facing Direction.S
# Move Direction.S by 24, now at -157, 194
# Rotating. Now facing Direction.W
# Move Direction.N by 4, now at -153, 194
# Move Direction.W by 3, now at -153, 191
# Move Direction.W by 54, now at -153, 137
# Move Direction.N by 3, now at -150, 137
# Move Direction.W by 14, now at -150, 123
# Move Direction.N by 1, now at -149, 123
# Move Direction.W by 19, now at -149, 104
# Move Direction.S by 3, now at -152, 104
# Move Direction.S by 2, now at -154, 104
# Rotating. Now facing Direction.N
# Move Direction.N by 1, now at -153, 104
# Move Direction.E by 4, now at -153, 108
# Move Direction.N by 3, now at -150, 108
# Move Direction.N by 3, now at -147, 108
# Rotating. Now facing Direction.E
# Move Direction.E by 4, now at -147, 112
# Move Direction.S by 2, now at -149, 112
# Rotating. Now facing Direction.N
# Move Direction.N by 5, now at -144, 112
# Rotating. Now facing Direction.W
# Move Direction.W by 5, now at -144, 107
# Move Direction.S by 2, now at -146, 107
# Rotating. Now facing Direction.S
# Move Direction.E by 4, now at -146, 111
# Move Direction.S by 61, now at -207, 111
# Move Direction.N by 2, now at -205, 111
# Move Direction.W by 5, now at -205, 106
# Move Direction.S by 84, now at -289, 106
# Rotating. Now facing Direction.E
# Move Direction.S by 1, now at -290, 106
# Move Direction.E by 1, now at -290, 107
# Move Direction.E by 18, now at -290, 125
# Move Direction.S by 3, now at -293, 125
# Move Direction.E by 4, now at -293, 129
# Move Direction.E by 97, now at -293, 226
# Move Direction.N by 2, now at -291, 226
# Rotating. Now facing Direction.S
# Move Direction.E by 5, now at -291, 231
# Move Direction.S by 79, now at -370, 231
# Rotating. Now facing Direction.N
# Move Direction.N by 12, now at -358, 231
# Rotating. Now facing Direction.S
# Move Direction.S by 93, now at -451, 231
# Rotating. Now facing Direction.N
# Move Direction.N by 1, now at -450, 231
# Move Direction.S by 5, now at -455, 231
# Move Direction.E by 2, now at -455, 233
# Move Direction.N by 5, now at -450, 233
# Move Direction.E by 5, now at -450, 238
# Rotating. Now facing Direction.S
# Move Direction.S by 3, now at -453, 238
# Rotating. Now facing Direction.E
# Move Direction.E by 85, now at -453, 323
# Move Direction.S by 4, now at -457, 323
# Rotating. Now facing Direction.S
# Move Direction.S by 2, now at -459, 323
# Move Direction.W by 3, now at -459, 320
# Rotating. Now facing Direction.W
# Move Direction.W by 87, now at -459, 233
# Rotating. Now facing Direction.S
# Move Direction.S by 33, now at -492, 233
# Move Direction.W by 2, now at -492, 231
# Move Direction.S by 22, now at -514, 231
# Move Direction.W by 3, now at -514, 228
# Move Direction.W by 2, now at -514, 226
# Move Direction.N by 4, now at -510, 226
# Move Direction.S by 83, now at -593, 226
# Rotating. Now facing Direction.E
# Move Direction.S by 2, now at -595, 226
# Move Direction.W by 5, now at -595, 221
# Move Direction.S by 5, now at -600, 221
# Move Direction.E by 99, now at -600, 320
# Move Direction.E by 1, now at -600, 321
# Rotating. Now facing Direction.W
# Move Direction.W by 81, now at -600, 240
# Move Direction.S by 2, now at -602, 240
# Rotating. Now facing Direction.S
# Move Direction.N by 3, now at -599, 240
# Move Direction.E by 5, now at -599, 245
# Move Direction.N by 3, now at -596, 245
# Rotating. Now facing Direction.E
# Move Direction.S by 5, now at -601, 245
# Move Direction.E by 91, now at -601, 336
# Rotating. Now facing Direction.N
# Move Direction.N by 68, now at -533, 336
# Rotating. Now facing Direction.W
# Move Direction.N by 2, now at -531, 336
# Move Direction.E by 3, now at -531, 339
# Move Direction.N by 5, now at -526, 339
# Rotating. Now facing Direction.S
# Move Direction.S by 3, now at -529, 339
# Move Direction.E by 1, now at -529, 340
# Rotating. Now facing Direction.E
# Move Direction.E by 2, now at -529, 342
# Move Direction.N by 1, now at -528, 342
# Move Direction.W by 4, now at -528, 338
# Move Direction.E by 53, now at -528, 391
# Move Direction.S by 4, now at -532, 391
# Move Direction.E by 47, now at -532, 438
# Rotating. Now facing Direction.S
# Move Direction.S by 5, now at -537, 438
# Move Direction.W by 2, now at -537, 436
# Move Direction.S by 99, now at -636, 436
# Move Direction.W by 4, now at -636, 432
# Rotating. Now facing Direction.N
# Move Direction.E by 4, now at -636, 436
# Rotating. Now facing Direction.E
# Move Direction.E by 3, now at -636, 439
# Move Direction.N by 3, now at -633, 439
# Move Direction.E by 3, now at -633, 442
# Move Direction.E by 23, now at -633, 465
# Rotating. Now facing Direction.N
# Move Direction.N by 5, now at -628, 465
# Rotating. Now facing Direction.W
# Move Direction.W by 68, now at -628, 397
# Rotating. Now facing Direction.E
# Move Direction.S by 4, now at -632, 397
# Move Direction.S by 2, now at -634, 397
# Move Direction.E by 71, now at -634, 468
# Move Direction.E by 2, now at -634, 470
# Move Direction.E by 7, now at -634, 477
# Move Direction.N by 4, now at -630, 477
# Move Direction.W by 3, now at -630, 474
# Rotating. Now facing Direction.W
# Move Direction.W by 17, now at -630, 457
# Rotating. Now facing Direction.N
# Move Direction.N by 5, now at -625, 457
# Move Direction.N by 70, now at -555, 457
# Move Direction.W by 3, now at -555, 454
# Move Direction.N by 82, now at -473, 454
# Rotating. Now facing Direction.W
# Rotating. Now facing Direction.S
# Move Direction.S by 2, now at -475, 454
# Rotating. Now facing Direction.E
# Move Direction.E by 10, now at -475, 464
# Move Direction.W by 1, now at -475, 463
# Move Direction.N by 2, now at -473, 463
# Rotating. Now facing Direction.S
# Move Direction.W by 3, now at -473, 460
# Move Direction.S by 48, now at -521, 460
# Rotating. Now facing Direction.E
# Move Direction.N by 5, now at -516, 460
# Move Direction.W by 1, now at -516, 459
# Move Direction.E by 42, now at -516, 501
# Move Direction.S by 5, now at -521, 501
# Rotating. Now facing Direction.W
# Move Direction.W by 99, now at -521, 402
# Rotating. Now facing Direction.S
# Move Direction.S by 28, now at -549, 402
# Move Direction.W by 4, now at -549, 398
# Rotating. Now facing Direction.N
# Move Direction.N by 2, now at -547, 398
# Move Direction.W by 5, now at -547, 393
# Move Direction.N by 3, now at -544, 393
# Move Direction.N by 79, now at -465, 393
# Move Direction.N by 5, now at -460, 393
# Move Direction.W by 1, now at -460, 392
# Rotating. Now facing Direction.E
# Move Direction.E by 8, now at -460, 400
# Rotating. Now facing Direction.W
# Move Direction.S by 4, now at -464, 400
# Rotating. Now facing Direction.S
# Move Direction.S by 2, now at -466, 400
# Move Direction.E by 2, now at -466, 402
# Move Direction.S by 60, now at -526, 402
# Move Direction.E by 5, now at -526, 407
# Rotating. Now facing Direction.E
# Move Direction.E by 93, now at -526, 500
# Move Direction.S by 3, now at -529, 500
# Move Direction.E by 17, now at -529, 517
# Move Direction.E by 2, now at -529, 519
# Move Direction.E by 6, now at -529, 525
# Move Direction.N by 4, now at -525, 525
# Move Direction.E by 80, now at -525, 605
# Rotating. Now facing Direction.N
# Move Direction.N by 98, now at -427, 605
# Move Direction.S by 3, now at -430, 605
# Rotating. Now facing Direction.W
# Move Direction.S by 5, now at -435, 605
# Move Direction.E by 1, now at -435, 606
# Move Direction.N by 4, now at -431, 606
# Move Direction.E by 2, now at -431, 608
# Move Direction.W by 67, now at -431, 541
# Rotating. Now facing Direction.N
# Move Direction.E by 2, now at -431, 543
# Rotating. Now facing Direction.W
# Move Direction.W by 5, now at -431, 538
# Move Direction.W by 32, now at -431, 506
# Move Direction.W by 1, now at -431, 505
# Move Direction.S by 2, now at -433, 505
# Rotating. Now facing Direction.S
# Move Direction.S by 4, now at -437, 505
# Move Direction.W by 4, now at -437, 501
# Move Direction.N by 1, now at -436, 501
# Move Direction.S by 74, now at -510, 501
# Move Direction.W by 3, now at -510, 498
# Rotating. Now facing Direction.W
# Move Direction.W by 24, now at -510, 474
# Move Direction.N by 5, now at -505, 474
# Rotating. Now facing Direction.N
# Move Direction.N by 74, now at -431, 474
# Move Direction.E by 5, now at -431, 479
# Rotating. Now facing Direction.W
# Move Direction.W by 4, now at -431, 475
# Rotating. Now facing Direction.E
# Move Direction.E by 51, now at -431, 526
# Move Direction.W by 2, now at -431, 524
# Rotating. Now facing Direction.W
# Move Direction.W by 36, now at -431, 488
# Move Direction.E by 5, now at -431, 493
# Move Direction.E by 5, now at -431, 498
# Move Direction.N by 4, now at -427, 498
# Move Direction.W by 53, now at -427, 445
# Move Direction.S by 2, now at -429, 445
# Move Direction.W by 56, now at -429, 389
# Move Direction.S by 5, now at -434, 389
# Move Direction.S by 2, now at -436, 389
# Move Direction.W by 31, now at -436, 358
# Move Direction.W by 5, now at -436, 353
# Move Direction.N by 5, now at -431, 353
# Rotating. Now facing Direction.S
# Move Direction.S by 1, now at -432, 353
# Move Direction.E by 2, now at -432, 355
# Rotating. Now facing Direction.E
# Move Direction.N by 2, now at -430, 355
# Move Direction.W by 4, now at -430, 351
# Move Direction.E by 5, now at -430, 356
# Rotating. Now facing Direction.N
# Move Direction.S by 2, now at -432, 356
# Move Direction.E by 5, now at -432, 361
# Move Direction.N by 62, now at -370, 361
# Rotating. Now facing Direction.W
# Move Direction.E by 3, now at -370, 364
# Rotating. Now facing Direction.S
# Move Direction.S by 41, now at -411, 364
# Move Direction.E by 5, now at -411, 369
# Move Direction.S by 32, now at -443, 369
# Rotating. Now facing Direction.W
# Move Direction.E by 4, now at -443, 373
# Rotating. Now facing Direction.N
# Move Direction.N by 1, now at -442, 373
# Rotating. Now facing Direction.W
# Move Direction.N by 5, now at -437, 373
# Move Direction.E by 5, now at -437, 378
# Rotating. Now facing Direction.E
# Move Direction.E by 1, now at -437, 379
# Move Direction.N by 3, now at -434, 379
# Rotating. Now facing Direction.S
# Move Direction.W by 4, now at -434, 375
# Move Direction.S by 86, now at -520, 375
# Move Direction.S by 8, now at -528, 375
# Move Direction.S by 1, now at -529, 375
# Rotating. Now facing Direction.W
# Move Direction.N by 4, now at -525, 375
# Rotating. Now facing Direction.S
# Move Direction.N by 4, now at -521, 375
# Move Direction.W by 3, now at -521, 372
# Move Direction.S by 39, now at -560, 372
# Rotating. Now facing Direction.W
# Move Direction.S by 4, now at -564, 372
# Move Direction.E by 2, now at -564, 374
# Move Direction.W by 59, now at -564, 315
# Move Direction.E by 4, now at -564, 319
# Move Direction.N by 1, now at -563, 319
# Move Direction.W by 72, now at -563, 247
# Move Direction.E by 1, now at -563, 248
# Move Direction.N by 2, now at -561, 248
# Move Direction.E by 4, now at -561, 252
# Move Direction.W by 93, now at -561, 159
# Move Direction.S by 2, now at -563, 159
# Move Direction.W by 10, now at -563, 149
# Rotating. Now facing Direction.E
# Move Direction.E by 74, now at -563, 223
# Move Direction.S by 1, now at -564, 223
# Move Direction.S by 1, now at -565, 223
# Move Direction.E by 67, now at -565, 290
# Rotating. Now facing Direction.S
# Move Direction.E by 5, now at -565, 295
# Move Direction.S by 66, now at -631, 295
# Rotating. Now facing Direction.E
# Move Direction.E by 27, now at -631, 322
# Move Direction.S by 2, now at -633, 322
# Rotating. Now facing Direction.N
# Move Direction.N by 11, now at -622, 322
# Move Direction.E by 4, now at -622, 326
# Move Direction.N by 3, now at -619, 326
# Move Direction.N by 32, now at -587, 326
# Rotating. Now facing Direction.S
# Move Direction.S by 4, now at -591, 326
# Move Direction.S by 92, now at -683, 326
# Rotating. Now facing Direction.E
# Move Direction.N by 1, now at -682, 326
# Move Direction.E by 3, now at -682, 329
# Rotating. Now facing Direction.W
# Move Direction.W by 9, now at -682, 320
# Rotating. Now facing Direction.N
# Move Direction.N by 31, now at -651, 320
# Move Direction.E by 5, now at -651, 325
# Rotating. Now facing Direction.W
# Move Direction.N by 2, now at -649, 325
# Move Direction.W by 13, now at -649, 312
# Move Direction.E by 2, now at -649, 314
# Rotating. Now facing Direction.S
# Move Direction.S by 52, now at -701, 314
# Move Direction.W by 3, now at -701, 311
# Rotating. Now facing Direction.N
# Move Direction.E by 3, now at -701, 314
# Move Direction.S by 3, now at -704, 314
# Rotating. Now facing Direction.E
# Move Direction.E by 67, now at -704, 381
# Move Direction.N by 1, now at -703, 381
# Move Direction.E by 75, now at -703, 456
# Rotating. Now facing Direction.N
# Move Direction.W by 5, now at -703, 451
# Move Direction.N by 3, now at -700, 451
# Move Direction.W by 3, now at -700, 448
# Rotating. Now facing Direction.E
# Move Direction.E by 76, now at -700, 524
# Rotating. Now facing Direction.N
# Move Direction.S by 4, now at -704, 524
# Move Direction.E by 2, now at -704, 526
# Rotating. Now facing Direction.W
# Move Direction.W by 2, now at -704, 524
# Rotating. Now facing Direction.S
# Rotating. Now facing Direction.W
# Move Direction.N by 1, now at -703, 524
# Move Direction.W by 77, now at -703, 447
# Move Direction.E by 2, now at -703, 449
# Rotating. Now facing Direction.E
# Move Direction.E by 4, now at -703, 453
# Rotating. Now facing Direction.N
# Move Direction.N by 65, now at -638, 453
# Move Direction.N by 3, now at -635, 453
# Rotating. Now facing Direction.S
# Move Direction.S by 1, now at -636, 453
# Move Direction.W by 2, now at -636, 451
# Move Direction.N by 5, now at -631, 451
# Move Direction.S by 97, now at -728, 451
# Move Direction.S by 1, now at -729, 451
# Move Direction.W by 2, now at -729, 449
# Rotating. Now facing Direction.E
# Move Direction.E by 81, now at -729, 530
# Rotating. Now facing Direction.S
# Move Direction.S by 4, now at -733, 530
# Move Direction.S by 85, now at -818, 530
# Rotating. Now facing Direction.N
# Move Direction.N by 45, now at -773, 530
# Move Direction.W by 3, now at -773, 527
# Move Direction.N by 2, now at -771, 527
# Move Direction.N by 5, now at -766, 527
# Move Direction.W by 4, now at -766, 523
# Rotating. Now facing Direction.E
# Move Direction.N by 4, now at -762, 523
# Move Direction.E by 3, now at -762, 526
# Move Direction.N by 5, now at -757, 526
# Move Direction.W by 4, now at -757, 522
# Move Direction.E by 29, now at -757, 551
# Move Direction.E by 5, now at -757, 556
# Rotating. Now facing Direction.W
# Move Direction.N by 1, now at -756, 556
# Rotating. Now facing Direction.E
# Move Direction.E by 17, now at -756, 573
# Move Direction.E by 3, now at -756, 576
# Rotating. Now facing Direction.S
# Move Direction.W by 1, now at -756, 575
# Move Direction.S by 62, now at -818, 575
# Move Direction.N by 3, now at -815, 575
# Move Direction.S by 87, now at -902, 575
# Rotating. Now facing Direction.E
# Move Direction.W by 5, now at -902, 570
# Move Direction.S by 5, now at -907, 570
# Move Direction.E by 42, now at -907, 612
# Move Direction.W by 5, now at -907, 607
# Move Direction.E by 72, now at -907, 679
# Rotating. Now facing Direction.S
# Move Direction.E by 3, now at -907, 682
# Move Direction.S by 11, now at -918, 682
# Rotating. Now facing Direction.W
# Move Direction.W by 14, now at -918, 668
# Move Direction.S by 3, now at -921, 668
# Rotating. Now facing Direction.N
# Move Direction.N by 4, now at -917, 668
# Move Direction.E by 3, now at -917, 671
# Rotating. Now facing Direction.E
# Move Direction.W by 5, now at -917, 666
# Move Direction.S by 4, now at -921, 666
# Move Direction.E by 5, now at -921, 671
# Rotating. Now facing Direction.N
# Move Direction.N by 35, now at -886, 671
# Move Direction.E by 3, now at -886, 674
# Move Direction.W by 3, now at -886, 671
# Move Direction.N by 1, now at -885, 671
# Rotating. Now facing Direction.E
# Move Direction.S by 1, now at -886, 671
# Move Direction.W by 3, now at -886, 668
# Rotating. Now facing Direction.W
# Move Direction.W by 80, now at -886, 588
# Move Direction.E by 2, now at -886, 590
# Move Direction.W by 24, now at -886, 566
# Move Direction.E by 1, now at -886, 567
# Rotating. Now facing Direction.N
# Move Direction.N by 23, now at -863, 567
# Move Direction.S by 3, now at -866, 567
# Rotating. Now facing Direction.W
# Move Direction.W by 4, now at -866, 563
# Move Direction.W by 37, now at -866, 526
# Rotating. Now facing Direction.S
# Move Direction.S by 55, now at -921, 526
# Move Direction.S by 3, now at -924, 526
# Move Direction.N by 4, now at -920, 526
# Move Direction.N by 5, now at -915, 526
# Rotating. Now facing Direction.E
# Move Direction.N by 1, now at -914, 526
# Rotating. Now facing Direction.N
# Move Direction.N by 99, now at -815, 526
# Rotating. Now facing Direction.E
# Move Direction.N by 4, now at -811, 526
# Move Direction.E by 1, now at -811, 527
# Rotating. Now facing Direction.S
# Move Direction.S by 21, now at -832, 527
# Move Direction.N by 4, now at -828, 527
# Rotating. Now facing Direction.N
# Move Direction.N by 50, now at -778, 527
# Move Direction.S by 4, now at -782, 527
# Move Direction.W by 2, now at -782, 525
# Move Direction.N by 43, now at -739, 525
# Rotating. Now facing Direction.S
# Move Direction.S by 7, now at -746, 525
# Move Direction.S by 4, now at -750, 525
# Move Direction.W by 1, now at -750, 524
# Move Direction.E by 1, now at -750, 525
# Move Direction.N by 4, now at -746, 525
# Move Direction.E by 3, now at -746, 528
# Rotating. Now facing Direction.N
# Move Direction.N by 3, now at -743, 528
# Move Direction.S by 1, now at -744, 528
# Move Direction.N by 48, now at -696, 528
# Rotating. Now facing Direction.S
# Move Direction.S by 97, now at -793, 528
# Rotating. Now facing Direction.W
# Move Direction.W by 46, now at -793, 482
# Move Direction.W by 2, now at -793, 480
# Move Direction.W by 3, now at -793, 477
# Move Direction.W by 4, now at -793, 473
# Move Direction.N by 1, now at -792, 473
# Rotating. Now facing Direction.E
# Move Direction.N by 5, now at -787, 473
# Move Direction.E by 4, now at -787, 477
# Rotating. Now facing Direction.W
# Move Direction.S by 5, now at -792, 477
# Move Direction.W by 99, now at -792, 378
# Move Direction.N by 5, now at -787, 378
# Move Direction.E by 2, now at -787, 380
# Rotating. Now facing Direction.N
# Move Direction.S by 2, now at -789, 380
# Move Direction.W by 5, now at -789, 375
# Move Direction.N by 5, now at -784, 375
# Rotating. Now facing Direction.E
# Move Direction.E by 26, now at -784, 401
# Move Direction.W by 3, now at -784, 398
# Move Direction.N by 3, now at -781, 398
# Move Direction.E by 25, now at -781, 423
# Move Direction.E by 4, now at -781, 427
# Move Direction.S by 2, now at -783, 427
# Move Direction.E by 62, now at -783, 489
# Move Direction.S by 5, now at -788, 489
# Move Direction.E by 54, now at -788, 543
# Rotating. Now facing Direction.S
# Move Direction.S by 45, now at -833, 543
# Move Direction.S by 4, now at -837, 543
# Move Direction.S by 97, now at -934, 543
# Rotating. Now facing Direction.W
# Move Direction.W by 1, now at -934, 542
# Move Direction.W by 68, now at -934, 474
# Move Direction.N by 3, now at -931, 474
# Rotating. Now facing Direction.N
# Move Direction.N by 76, now at -855, 474
# Rotating. Now facing Direction.E
# Move Direction.N by 2, now at -853, 474
# Rotating. Now facing Direction.W
# Move Direction.N by 2, now at -851, 474
# Move Direction.W by 42, now at -851, 432
# Rotating. Now facing Direction.E
# Move Direction.E by 5, now at -851, 437
# Rotating. Now facing Direction.N
# Move Direction.W by 4, now at -851, 433
# Move Direction.N by 4, now at -847, 433
# Move Direction.N by 39, now at -808, 433
# Move Direction.N by 4, now at -804, 433
# Rotating. Now facing Direction.S
# Move Direction.W by 2, now at -804, 431
# Move Direction.N by 1, now at -803, 431
# Move Direction.S by 19, now at -822, 431
# Rotating. Now facing Direction.W
# Move Direction.W by 5, now at -822, 426
# Rotating. Now facing Direction.S
# Move Direction.N by 3, now at -819, 426
# Rotating. Now facing Direction.E
# Move Direction.E by 24, now at -819, 450
# Move Direction.S by 2, now at -821, 450
# Rotating. Now facing Direction.W
# Move Direction.N by 5, now at -816, 450
# Move Direction.E by 4, now at -816, 454
# Move Direction.W by 92, now at -816, 362
# Move Direction.N by 2, now at -814, 362
# Rotating. Now facing Direction.N
# Move Direction.N by 73, now at -741, 362
# Move Direction.W by 3, now at -741, 359
# Move Direction.S by 2, now at -743, 359
# Rotating. Now facing Direction.S
# Move Direction.S by 53, now at -796, 359
# Move Direction.S by 5, now at -801, 359
# Move Direction.W by 5, now at -801, 354
# Move Direction.W by 4, now at -801, 350
# Rotating. Now facing Direction.E
# Move Direction.S by 3, now at -804, 350
# Rotating. Now facing Direction.N
# Move Direction.N by 49, now at -755, 350
# Rotating. Now facing Direction.E
# Move Direction.W by 4, now at -755, 346
# Move Direction.N by 1, now at -754, 346
# Rotating. Now facing Direction.S
# Move Direction.N by 1, now at -753, 346
# Move Direction.E by 1, now at -753, 347
# Rotating. Now facing Direction.E
# Move Direction.E by 1, now at -753, 348
# Move Direction.E by 62, now at -753, 410
# Move Direction.N by 1, now at -752, 410
# Move Direction.E by 5, now at -752, 415
# Rotating. Now facing Direction.S
# Move Direction.S by 59, now at -811, 415
# Move Direction.S by 56, now at -867, 415
# Rotating. Now facing Direction.N
# Move Direction.N by 25, now at -842, 415
# Rotating. Now facing Direction.S
# Move Direction.W by 3, now at -842, 412
# Rotating. Now facing Direction.E
# Move Direction.N by 3, now at -839, 412
# Move Direction.E by 4, now at -839, 416
# Move Direction.S by 2, now at -841, 416
# Move Direction.S by 3, now at -844, 416
# Move Direction.E by 4, now at -844, 420
# Rotating. Now facing Direction.N
# Move Direction.E by 4, now at -844, 424
# Move Direction.N by 5, now at -839, 424
# Move Direction.N by 81, now at -758, 424
# Move Direction.S by 4, now at -762, 424
# Move Direction.N by 54, now at -708, 424
# Move Direction.S by 2, now at -710, 424
# Rotating. Now facing Direction.E
# Move Direction.S by 2, now at -712, 424
# Move Direction.E by 4, now at -712, 428
# Move Direction.W by 4, now at -712, 424
# Move Direction.N by 1, now at -711, 424
# Move Direction.E by 100, now at -711, 524
# Rotating. Now facing Direction.N
# Move Direction.S by 5, now at -716, 524
# Rotating. Now facing Direction.S
# Move Direction.S by 59, now at -775, 524
# Rotating. Now facing Direction.E
# Move Direction.E by 56, now at -775, 580
# Move Direction.S by 1, now at -776, 580
# Move Direction.E by 5, now at -776, 585
# Move Direction.E by 79, now at -776, 664
# Rotating. Now facing Direction.S
# Move Direction.N by 5, now at -771, 664
# Move Direction.W by 4, now at -771, 660
# Move Direction.N by 5, now at -766, 660
# Move Direction.W by 4, now at -766, 656
# Move Direction.N by 3, now at -763, 656
# Rotating. Now facing Direction.N
# Move Direction.W by 5, now at -763, 651
# Rotating. Now facing Direction.E
# Move Direction.S by 5, now at -768, 651
# Move Direction.E by 92, now at -768, 743
# Move Direction.S by 4, now at -772, 743
# Move Direction.E by 4, now at -772, 747
# Move Direction.E by 17, now at -772, 764
# Move Direction.N by 2, now at -770, 764
# Rotating. Now facing Direction.N
# Move Direction.S by 2, now at -772, 764
# Rotating. Now facing Direction.W
# Move Direction.W by 62, now at -772, 702
# Move Direction.N by 1, now at -771, 702
# Move Direction.W by 2, now at -771, 700
# Move Direction.W by 2, now at -771, 698
# Move Direction.N by 4, now at -767, 698
# Move Direction.W by 40, now at -767, 658
# Rotating. Now facing Direction.N
# Move Direction.S by 2, now at -769, 658
# Rotating. Now facing Direction.S
# Move Direction.E by 5, now at -769, 663
# Move Direction.S by 4, now at -773, 663
# Move Direction.S by 100, now at -873, 663
# Move Direction.W by 2, now at -873, 661
# Move Direction.S by 27, now at -900, 661
# Move Direction.W by 5, now at -900, 656
# Rotating. Now facing Direction.W
# Move Direction.S by 1, now at -901, 656
# Rotating. Now facing Direction.S
# Move Direction.E by 5, now at -901, 661
# Rotating. Now facing Direction.W
# Move Direction.W by 5, now at -901, 656
# Rotating. Now facing Direction.N
# Rotating. Now facing Direction.S
# Move Direction.S by 3, now at -904, 656
# Move Direction.E by 2, now at -904, 658
# Move Direction.S by 75, now at -979, 658
# Move Direction.N by 5, now at -974, 658
# Rotating. Now facing Direction.N
# Move Direction.N by 8, now at -966, 658
# Move Direction.S by 5, now at -971, 658
# Move Direction.N by 64, now at -907, 658
# 1565

# %% [markdown]
# ### Part 2
# Almost all of the actions indicate how to move a waypoint which is relative to the ship's position:
#
#     Action N means to move the waypoint north by the given value.
#     Action S means to move the waypoint south by the given value.
#     Action E means to move the waypoint east by the given value.
#     Action W means to move the waypoint west by the given value.
#     Action L means to rotate the waypoint around the ship left (counter-clockwise) the given number of degrees.
#     Action R means to rotate the waypoint around the ship right (clockwise) the given number of degrees.
#     Action F means to move forward to the waypoint a number of times equal to the given value.
#
# The waypoint starts 10 units east and 1 unit north relative to the ship. The waypoint is relative to the ship; that is, if the ship moves, the waypoint moves with it.

# %%
# Refactor of everything above
from enum import Enum

INPUT_FILE = 'input_d12.txt'
EXAMPLE_FILE = 'input2_d12.txt'

class Direction(Enum):
    N = 0
    E = 90
    S = 180
    W = 270
        
class Point:
    '''
    A Point has 2D coordinates on the X (east-west) and Y (north-south) axes
    '''
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    
    def move(self, direction, distance):
        '''
        For a move in a given direction, updates state accordingly
        :param direction: a Direction enum
        :param distance: the integer distance to move
        '''
        if direction == Direction.N:
            self.y += distance
        elif direction == Direction.S:
            self.y -= distance
        elif direction == Direction.E:
            self.x += distance
        elif direction == Direction.W:
            self.x -= distance
        else:
            raise IllegalArgument('Illegal direction')

    def move_x_y(self, dxdy):
        '''
        Moves the coordinates by the amounts specified
        :param dxdy: tuple of the amount to move in the x and y axes
        '''
        self.x += dxdy[0]
        self.y += dxdy[1]
        
    def manhattan(self):
        '''
        :return: The Manhattan distance relative to the origin
        '''
        return abs(self.x) + abs(self.y)

    def __repr__(self):
        return f'<{self.__class__} ({self.x}, {self.y})>'

class Waypoint(Point):
    '''
    A Waypoint is a Point that has the ability to rotate around its origin
    '''
    def rotate(self, right_left, degree):
        '''
        Rotates the waypoint around the origin in 90-degree increments
        :param right_left: 'R' for clockwise or 'L' for counter-clockwise
        :param degree: number of degrees to rotate (in 90-degree steps)
        '''
        num_turns = (degree // 90) % 4
        if right_left == 'L' and num_turns != 0:
            num_turns = 4 - num_turns
        for _ in range(num_turns):
            self.x, self.y = self.y, -self.x
            
    def __mul__(self, other):
        if isinstance(other, int):
            return (other * self.x, other * self.y)
        else:
            raise NotImplemented
                
class NavSystem:
    '''
    NavSystem has a Point representing ship location and a Waypoint
    vector from the ship
    '''
    
    def __init__(self, wp_x=10, wp_y=1):
        '''
        :param wp_x: Starting x position for waypoint relative to ship
        :param wp_y: Starting y position for waypoint relative to ship
        '''
        self.waypoint = Waypoint(wp_x, wp_y)
        self.ship = Point(0,0)
        
    def process_action(self, command, param):
        '''
        Processes an individual action according to the revised Part 2 definitions
        :param command: One of [N, S, E, W, L, R, F]
        :param param: The parameter--units to move when [N,S,E,W,F], or degrees with [R,L]
        '''
        if command in ['R','L']:
            self.waypoint.rotate(command, param)
        elif command == 'F':
            self.ship.move_x_y(self.waypoint * param)
        elif command in ['N','S','E','W']:
            self.waypoint.move(Direction[command], param)
        else:
            raise IllegalArgument('Unrecognized command')
            
        self.print_loc(command, param)
            
    def load_actions(self, input_file):
        '''
        Loads actions from a file
        :param input_file: string filename
        '''
        with open(input_file) as fh:
            for line in fh.readlines():
                self.process_action(line[0], int(line[1:]))
                
    def print_loc(self, cmd, param):
        print(f'{cmd} {param}: ship at {self.ship.x, self.ship.y}; waypoint {self.waypoint.x, self.waypoint.y}')

# %%
p = Point(10,3)
p.move_x_y((2,2))
assert (p.x, p.y) == (12,5)
assert p.manhattan() == 17

# %%
wp = Waypoint(10,3)
assert wp * 3 == (30, 9)
wp.move(Direction.N, 3)
wp.move(Direction.E, 3)
assert wp.x, wp.y == (13,6)
wp.rotate('L', 90)
assert wp.x, wp.y == (6, -13)
wp.rotate('R', 180)
assert wp.x, wp.y == (13, 6)

# %%
# Example data test
ex = NavSystem()
ex.load_actions(EXAMPLE_FILE)
assert ex.ship.manhattan() == 286
# Out:
# F 10: ship at (100, 10); waypoint (10, 1)
# N 3: ship at (100, 10); waypoint (10, 4)
# F 7: ship at (170, 38); waypoint (10, 4)
# R 90: ship at (170, 38); waypoint (4, -10)
# F 11: ship at (214, -72); waypoint (4, -10)

# %%
# Part 2 actual data
nav = NavSystem(10,1)
nav.load_actions(INPUT_FILE)
# Out:
# E 5: ship at (0, 0); waypoint (15, 1)
# R 90: ship at (0, 0); waypoint (1, -15)
# E 5: ship at (0, 0); waypoint (6, -15)
# L 90: ship at (0, 0); waypoint (15, 6)
# F 80: ship at (1200, 480); waypoint (15, 6)
# L 90: ship at (1200, 480); waypoint (-6, 15)
# E 3: ship at (1200, 480); waypoint (-3, 15)
# N 5: ship at (1200, 480); waypoint (-3, 20)
# F 10: ship at (1170, 680); waypoint (-3, 20)
# S 2: ship at (1170, 680); waypoint (-3, 18)
# W 1: ship at (1170, 680); waypoint (-4, 18)
# F 98: ship at (778, 2444); waypoint (-4, 18)
# L 180: ship at (778, 2444); waypoint (4, -18)
# W 1: ship at (778, 2444); waypoint (3, -18)
# F 55: ship at (943, 1454); waypoint (3, -18)
# L 90: ship at (943, 1454); waypoint (18, 3)
# F 73: ship at (2257, 1673); waypoint (18, 3)
# N 1: ship at (2257, 1673); waypoint (18, 4)
# E 3: ship at (2257, 1673); waypoint (21, 4)
# S 2: ship at (2257, 1673); waypoint (21, 2)
# E 5: ship at (2257, 1673); waypoint (26, 2)
# R 90: ship at (2257, 1673); waypoint (2, -26)
# E 2: ship at (2257, 1673); waypoint (4, -26)
# S 4: ship at (2257, 1673); waypoint (4, -30)
# F 34: ship at (2393, 653); waypoint (4, -30)
# R 90: ship at (2393, 653); waypoint (-30, -4)
# W 2: ship at (2393, 653); waypoint (-32, -4)
# L 90: ship at (2393, 653); waypoint (4, -32)
# W 4: ship at (2393, 653); waypoint (0, -32)
# F 92: ship at (2393, -2291); waypoint (0, -32)
# R 90: ship at (2393, -2291); waypoint (-32, 0)
# W 4: ship at (2393, -2291); waypoint (-36, 0)
# N 5: ship at (2393, -2291); waypoint (-36, 5)
# R 90: ship at (2393, -2291); waypoint (5, 36)
# F 73: ship at (2758, 337); waypoint (5, 36)
# S 4: ship at (2758, 337); waypoint (5, 32)
# W 3: ship at (2758, 337); waypoint (2, 32)
# N 4: ship at (2758, 337); waypoint (2, 36)
# R 90: ship at (2758, 337); waypoint (36, -2)
# S 3: ship at (2758, 337); waypoint (36, -5)
# W 3: ship at (2758, 337); waypoint (33, -5)
# N 4: ship at (2758, 337); waypoint (33, -1)
# F 30: ship at (3748, 307); waypoint (33, -1)
# S 5: ship at (3748, 307); waypoint (33, -6)
# E 4: ship at (3748, 307); waypoint (37, -6)
# R 90: ship at (3748, 307); waypoint (-6, -37)
# W 5: ship at (3748, 307); waypoint (-11, -37)
# R 90: ship at (3748, 307); waypoint (-37, 11)
# S 3: ship at (3748, 307); waypoint (-37, 8)
# E 5: ship at (3748, 307); waypoint (-32, 8)
# L 180: ship at (3748, 307); waypoint (32, -8)
# E 2: ship at (3748, 307); waypoint (34, -8)
# S 4: ship at (3748, 307); waypoint (34, -12)
# E 4: ship at (3748, 307); waypoint (38, -12)
# S 2: ship at (3748, 307); waypoint (38, -14)
# W 3: ship at (3748, 307); waypoint (35, -14)
# F 19: ship at (4413, 41); waypoint (35, -14)
# N 2: ship at (4413, 41); waypoint (35, -12)
# F 53: ship at (6268, -595); waypoint (35, -12)
# R 90: ship at (6268, -595); waypoint (-12, -35)
# W 4: ship at (6268, -595); waypoint (-16, -35)
# R 90: ship at (6268, -595); waypoint (-35, 16)
# N 3: ship at (6268, -595); waypoint (-35, 19)
# W 5: ship at (6268, -595); waypoint (-40, 19)
# R 90: ship at (6268, -595); waypoint (19, 40)
# W 4: ship at (6268, -595); waypoint (15, 40)
# F 68: ship at (7288, 2125); waypoint (15, 40)
# W 4: ship at (7288, 2125); waypoint (11, 40)
# N 5: ship at (7288, 2125); waypoint (11, 45)
# F 26: ship at (7574, 3295); waypoint (11, 45)
# W 4: ship at (7574, 3295); waypoint (7, 45)
# F 11: ship at (7651, 3790); waypoint (7, 45)
# L 90: ship at (7651, 3790); waypoint (-45, 7)
# E 5: ship at (7651, 3790); waypoint (-40, 7)
# L 90: ship at (7651, 3790); waypoint (-7, -40)
# F 67: ship at (7182, 1110); waypoint (-7, -40)
# W 3: ship at (7182, 1110); waypoint (-10, -40)
# S 3: ship at (7182, 1110); waypoint (-10, -43)
# F 15: ship at (7032, 465); waypoint (-10, -43)
# E 4: ship at (7032, 465); waypoint (-6, -43)
# S 4: ship at (7032, 465); waypoint (-6, -47)
# E 5: ship at (7032, 465); waypoint (-1, -47)
# S 1: ship at (7032, 465); waypoint (-1, -48)
# F 11: ship at (7021, -63); waypoint (-1, -48)
# R 90: ship at (7021, -63); waypoint (-48, 1)
# E 3: ship at (7021, -63); waypoint (-45, 1)
# F 46: ship at (4951, -17); waypoint (-45, 1)
# R 90: ship at (4951, -17); waypoint (1, 45)
# F 40: ship at (4991, 1783); waypoint (1, 45)
# E 3: ship at (4991, 1783); waypoint (4, 45)
# R 90: ship at (4991, 1783); waypoint (45, -4)
# F 35: ship at (6566, 1643); waypoint (45, -4)
# R 180: ship at (6566, 1643); waypoint (-45, 4)
# E 3: ship at (6566, 1643); waypoint (-42, 4)
# S 5: ship at (6566, 1643); waypoint (-42, -1)
# L 90: ship at (6566, 1643); waypoint (1, -42)
# E 3: ship at (6566, 1643); waypoint (4, -42)
# F 63: ship at (6818, -1003); waypoint (4, -42)
# E 4: ship at (6818, -1003); waypoint (8, -42)
# F 56: ship at (7266, -3355); waypoint (8, -42)
# N 2: ship at (7266, -3355); waypoint (8, -40)
# E 1: ship at (7266, -3355); waypoint (9, -40)
# R 90: ship at (7266, -3355); waypoint (-40, -9)
# N 3: ship at (7266, -3355); waypoint (-40, -6)
# F 42: ship at (5586, -3607); waypoint (-40, -6)
# W 2: ship at (5586, -3607); waypoint (-42, -6)
# S 4: ship at (5586, -3607); waypoint (-42, -10)
# N 3: ship at (5586, -3607); waypoint (-42, -7)
# R 90: ship at (5586, -3607); waypoint (-7, 42)
# W 2: ship at (5586, -3607); waypoint (-9, 42)
# R 90: ship at (5586, -3607); waypoint (42, 9)
# F 45: ship at (7476, -3202); waypoint (42, 9)
# N 5: ship at (7476, -3202); waypoint (42, 14)
# L 90: ship at (7476, -3202); waypoint (-14, 42)
# F 38: ship at (6944, -1606); waypoint (-14, 42)
# L 90: ship at (6944, -1606); waypoint (-42, -14)
# N 5: ship at (6944, -1606); waypoint (-42, -9)
# E 4: ship at (6944, -1606); waypoint (-38, -9)
# R 90: ship at (6944, -1606); waypoint (-9, 38)
# N 2: ship at (6944, -1606); waypoint (-9, 40)
# R 90: ship at (6944, -1606); waypoint (40, 9)
# S 4: ship at (6944, -1606); waypoint (40, 5)
# R 90: ship at (6944, -1606); waypoint (5, -40)
# N 3: ship at (6944, -1606); waypoint (5, -37)
# F 53: ship at (7209, -3567); waypoint (5, -37)
# R 90: ship at (7209, -3567); waypoint (-37, -5)
# F 72: ship at (4545, -3927); waypoint (-37, -5)
# S 5: ship at (4545, -3927); waypoint (-37, -10)
# E 3: ship at (4545, -3927); waypoint (-34, -10)
# F 98: ship at (1213, -4907); waypoint (-34, -10)
# L 90: ship at (1213, -4907); waypoint (10, -34)
# E 3: ship at (1213, -4907); waypoint (13, -34)
# F 56: ship at (1941, -6811); waypoint (13, -34)
# S 2: ship at (1941, -6811); waypoint (13, -36)
# F 29: ship at (2318, -7855); waypoint (13, -36)
# E 2: ship at (2318, -7855); waypoint (15, -36)
# W 3: ship at (2318, -7855); waypoint (12, -36)
# L 180: ship at (2318, -7855); waypoint (-12, 36)
# S 4: ship at (2318, -7855); waypoint (-12, 32)
# F 31: ship at (1946, -6863); waypoint (-12, 32)
# S 2: ship at (1946, -6863); waypoint (-12, 30)
# R 90: ship at (1946, -6863); waypoint (30, 12)
# N 5: ship at (1946, -6863); waypoint (30, 17)
# R 270: ship at (1946, -6863); waypoint (-17, 30)
# F 45: ship at (1181, -5513); waypoint (-17, 30)
# L 90: ship at (1181, -5513); waypoint (-30, -17)
# F 10: ship at (881, -5683); waypoint (-30, -17)
# N 5: ship at (881, -5683); waypoint (-30, -12)
# R 90: ship at (881, -5683); waypoint (-12, 30)
# E 5: ship at (881, -5683); waypoint (-7, 30)
# F 47: ship at (552, -4273); waypoint (-7, 30)
# R 90: ship at (552, -4273); waypoint (30, 7)
# S 3: ship at (552, -4273); waypoint (30, 4)
# F 98: ship at (3492, -3881); waypoint (30, 4)
# R 90: ship at (3492, -3881); waypoint (4, -30)
# F 85: ship at (3832, -6431); waypoint (4, -30)
# E 1: ship at (3832, -6431); waypoint (5, -30)
# L 90: ship at (3832, -6431); waypoint (30, 5)
# S 4: ship at (3832, -6431); waypoint (30, 1)
# R 180: ship at (3832, -6431); waypoint (-30, -1)
# N 4: ship at (3832, -6431); waypoint (-30, 3)
# L 90: ship at (3832, -6431); waypoint (-3, -30)
# W 5: ship at (3832, -6431); waypoint (-8, -30)
# R 90: ship at (3832, -6431); waypoint (-30, 8)
# E 4: ship at (3832, -6431); waypoint (-26, 8)
# L 90: ship at (3832, -6431); waypoint (-8, -26)
# F 24: ship at (3640, -7055); waypoint (-8, -26)
# R 90: ship at (3640, -7055); waypoint (-26, 8)
# N 4: ship at (3640, -7055); waypoint (-26, 12)
# W 3: ship at (3640, -7055); waypoint (-29, 12)
# F 54: ship at (2074, -6407); waypoint (-29, 12)
# N 3: ship at (2074, -6407); waypoint (-29, 15)
# F 14: ship at (1668, -6197); waypoint (-29, 15)
# N 1: ship at (1668, -6197); waypoint (-29, 16)
# F 19: ship at (1117, -5893); waypoint (-29, 16)
# S 3: ship at (1117, -5893); waypoint (-29, 13)
# S 2: ship at (1117, -5893); waypoint (-29, 11)
# R 90: ship at (1117, -5893); waypoint (11, 29)
# N 1: ship at (1117, -5893); waypoint (11, 30)
# E 4: ship at (1117, -5893); waypoint (15, 30)
# F 3: ship at (1162, -5803); waypoint (15, 30)
# N 3: ship at (1162, -5803); waypoint (15, 33)
# R 90: ship at (1162, -5803); waypoint (33, -15)
# F 4: ship at (1294, -5863); waypoint (33, -15)
# S 2: ship at (1294, -5863); waypoint (33, -17)
# L 90: ship at (1294, -5863); waypoint (17, 33)
# N 5: ship at (1294, -5863); waypoint (17, 38)
# L 90: ship at (1294, -5863); waypoint (-38, 17)
# W 5: ship at (1294, -5863); waypoint (-43, 17)
# S 2: ship at (1294, -5863); waypoint (-43, 15)
# L 90: ship at (1294, -5863); waypoint (-15, -43)
# E 4: ship at (1294, -5863); waypoint (-11, -43)
# F 61: ship at (623, -8486); waypoint (-11, -43)
# N 2: ship at (623, -8486); waypoint (-11, -41)
# W 5: ship at (623, -8486); waypoint (-16, -41)
# F 84: ship at (-721, -11930); waypoint (-16, -41)
# R 270: ship at (-721, -11930); waypoint (41, -16)
# S 1: ship at (-721, -11930); waypoint (41, -17)
# E 1: ship at (-721, -11930); waypoint (42, -17)
# F 18: ship at (35, -12236); waypoint (42, -17)
# S 3: ship at (35, -12236); waypoint (42, -20)
# E 4: ship at (35, -12236); waypoint (46, -20)
# F 97: ship at (4497, -14176); waypoint (46, -20)
# N 2: ship at (4497, -14176); waypoint (46, -18)
# R 90: ship at (4497, -14176); waypoint (-18, -46)
# E 5: ship at (4497, -14176); waypoint (-13, -46)
# F 79: ship at (3470, -17810); waypoint (-13, -46)
# R 180: ship at (3470, -17810); waypoint (13, 46)
# F 12: ship at (3626, -17258); waypoint (13, 46)
# R 180: ship at (3626, -17258); waypoint (-13, -46)
# F 93: ship at (2417, -21536); waypoint (-13, -46)
# L 180: ship at (2417, -21536); waypoint (13, 46)
# N 1: ship at (2417, -21536); waypoint (13, 47)
# S 5: ship at (2417, -21536); waypoint (13, 42)
# E 2: ship at (2417, -21536); waypoint (15, 42)
# N 5: ship at (2417, -21536); waypoint (15, 47)
# E 5: ship at (2417, -21536); waypoint (20, 47)
# L 180: ship at (2417, -21536); waypoint (-20, -47)
# S 3: ship at (2417, -21536); waypoint (-20, -50)
# L 90: ship at (2417, -21536); waypoint (50, -20)
# F 85: ship at (6667, -23236); waypoint (50, -20)
# S 4: ship at (6667, -23236); waypoint (50, -24)
# R 90: ship at (6667, -23236); waypoint (-24, -50)
# S 2: ship at (6667, -23236); waypoint (-24, -52)
# W 3: ship at (6667, -23236); waypoint (-27, -52)
# R 90: ship at (6667, -23236); waypoint (-52, 27)
# F 87: ship at (2143, -20887); waypoint (-52, 27)
# L 90: ship at (2143, -20887); waypoint (-27, -52)
# F 33: ship at (1252, -22603); waypoint (-27, -52)
# W 2: ship at (1252, -22603); waypoint (-29, -52)
# F 22: ship at (614, -23747); waypoint (-29, -52)
# W 3: ship at (614, -23747); waypoint (-32, -52)
# W 2: ship at (614, -23747); waypoint (-34, -52)
# N 4: ship at (614, -23747); waypoint (-34, -48)
# F 83: ship at (-2208, -27731); waypoint (-34, -48)
# L 90: ship at (-2208, -27731); waypoint (48, -34)
# S 2: ship at (-2208, -27731); waypoint (48, -36)
# W 5: ship at (-2208, -27731); waypoint (43, -36)
# S 5: ship at (-2208, -27731); waypoint (43, -41)
# F 99: ship at (2049, -31790); waypoint (43, -41)
# E 1: ship at (2049, -31790); waypoint (44, -41)
# L 180: ship at (2049, -31790); waypoint (-44, 41)
# F 81: ship at (-1515, -28469); waypoint (-44, 41)
# S 2: ship at (-1515, -28469); waypoint (-44, 39)
# L 90: ship at (-1515, -28469); waypoint (-39, -44)
# N 3: ship at (-1515, -28469); waypoint (-39, -41)
# E 5: ship at (-1515, -28469); waypoint (-34, -41)
# N 3: ship at (-1515, -28469); waypoint (-34, -38)
# L 90: ship at (-1515, -28469); waypoint (38, -34)
# S 5: ship at (-1515, -28469); waypoint (38, -39)
# F 91: ship at (1943, -32018); waypoint (38, -39)
# R 270: ship at (1943, -32018); waypoint (39, 38)
# F 68: ship at (4595, -29434); waypoint (39, 38)
# L 90: ship at (4595, -29434); waypoint (-38, 39)
# N 2: ship at (4595, -29434); waypoint (-38, 41)
# E 3: ship at (4595, -29434); waypoint (-35, 41)
# N 5: ship at (4595, -29434); waypoint (-35, 46)
# L 90: ship at (4595, -29434); waypoint (-46, -35)
# S 3: ship at (4595, -29434); waypoint (-46, -38)
# E 1: ship at (4595, -29434); waypoint (-45, -38)
# L 90: ship at (4595, -29434); waypoint (38, -45)
# E 2: ship at (4595, -29434); waypoint (40, -45)
# N 1: ship at (4595, -29434); waypoint (40, -44)
# W 4: ship at (4595, -29434); waypoint (36, -44)
# F 53: ship at (6503, -31766); waypoint (36, -44)
# S 4: ship at (6503, -31766); waypoint (36, -48)
# F 47: ship at (8195, -34022); waypoint (36, -48)
# R 90: ship at (8195, -34022); waypoint (-48, -36)
# S 5: ship at (8195, -34022); waypoint (-48, -41)
# W 2: ship at (8195, -34022); waypoint (-50, -41)
# F 99: ship at (3245, -38081); waypoint (-50, -41)
# W 4: ship at (3245, -38081); waypoint (-54, -41)
# R 180: ship at (3245, -38081); waypoint (54, 41)
# E 4: ship at (3245, -38081); waypoint (58, 41)
# R 90: ship at (3245, -38081); waypoint (41, -58)
# E 3: ship at (3245, -38081); waypoint (44, -58)
# N 3: ship at (3245, -38081); waypoint (44, -55)
# E 3: ship at (3245, -38081); waypoint (47, -55)
# F 23: ship at (4326, -39346); waypoint (47, -55)
# L 90: ship at (4326, -39346); waypoint (55, 47)
# N 5: ship at (4326, -39346); waypoint (55, 52)
# L 90: ship at (4326, -39346); waypoint (-52, 55)
# F 68: ship at (790, -35606); waypoint (-52, 55)
# R 180: ship at (790, -35606); waypoint (52, -55)
# S 4: ship at (790, -35606); waypoint (52, -59)
# S 2: ship at (790, -35606); waypoint (52, -61)
# F 71: ship at (4482, -39937); waypoint (52, -61)
# E 2: ship at (4482, -39937); waypoint (54, -61)
# F 7: ship at (4860, -40364); waypoint (54, -61)
# N 4: ship at (4860, -40364); waypoint (54, -57)
# W 3: ship at (4860, -40364); waypoint (51, -57)
# L 180: ship at (4860, -40364); waypoint (-51, 57)
# F 17: ship at (3993, -39395); waypoint (-51, 57)
# R 90: ship at (3993, -39395); waypoint (57, 51)
# N 5: ship at (3993, -39395); waypoint (57, 56)
# F 70: ship at (7983, -35475); waypoint (57, 56)
# W 3: ship at (7983, -35475); waypoint (54, 56)
# F 82: ship at (12411, -30883); waypoint (54, 56)
# L 90: ship at (12411, -30883); waypoint (-56, 54)
# L 90: ship at (12411, -30883); waypoint (-54, -56)
# S 2: ship at (12411, -30883); waypoint (-54, -58)
# L 90: ship at (12411, -30883); waypoint (58, -54)
# F 10: ship at (12991, -31423); waypoint (58, -54)
# W 1: ship at (12991, -31423); waypoint (57, -54)
# N 2: ship at (12991, -31423); waypoint (57, -52)
# R 90: ship at (12991, -31423); waypoint (-52, -57)
# W 3: ship at (12991, -31423); waypoint (-55, -57)
# F 48: ship at (10351, -34159); waypoint (-55, -57)
# L 90: ship at (10351, -34159); waypoint (57, -55)
# N 5: ship at (10351, -34159); waypoint (57, -50)
# W 1: ship at (10351, -34159); waypoint (56, -50)
# F 42: ship at (12703, -36259); waypoint (56, -50)
# S 5: ship at (12703, -36259); waypoint (56, -55)
# R 180: ship at (12703, -36259); waypoint (-56, 55)
# F 99: ship at (7159, -30814); waypoint (-56, 55)
# L 90: ship at (7159, -30814); waypoint (-55, -56)
# F 28: ship at (5619, -32382); waypoint (-55, -56)
# W 4: ship at (5619, -32382); waypoint (-59, -56)
# R 180: ship at (5619, -32382); waypoint (59, 56)
# N 2: ship at (5619, -32382); waypoint (59, 58)
# W 5: ship at (5619, -32382); waypoint (54, 58)
# N 3: ship at (5619, -32382); waypoint (54, 61)
# F 79: ship at (9885, -27563); waypoint (54, 61)
# N 5: ship at (9885, -27563); waypoint (54, 66)
# W 1: ship at (9885, -27563); waypoint (53, 66)
# R 90: ship at (9885, -27563); waypoint (66, -53)
# F 8: ship at (10413, -27987); waypoint (66, -53)
# L 180: ship at (10413, -27987); waypoint (-66, 53)
# S 4: ship at (10413, -27987); waypoint (-66, 49)
# L 90: ship at (10413, -27987); waypoint (-49, -66)
# S 2: ship at (10413, -27987); waypoint (-49, -68)
# E 2: ship at (10413, -27987); waypoint (-47, -68)
# F 60: ship at (7593, -32067); waypoint (-47, -68)
# E 5: ship at (7593, -32067); waypoint (-42, -68)
# L 90: ship at (7593, -32067); waypoint (68, -42)
# F 93: ship at (13917, -35973); waypoint (68, -42)
# S 3: ship at (13917, -35973); waypoint (68, -45)
# F 17: ship at (15073, -36738); waypoint (68, -45)
# E 2: ship at (15073, -36738); waypoint (70, -45)
# F 6: ship at (15493, -37008); waypoint (70, -45)
# N 4: ship at (15493, -37008); waypoint (70, -41)
# F 80: ship at (21093, -40288); waypoint (70, -41)
# L 90: ship at (21093, -40288); waypoint (41, 70)
# F 98: ship at (25111, -33428); waypoint (41, 70)
# S 3: ship at (25111, -33428); waypoint (41, 67)
# L 90: ship at (25111, -33428); waypoint (-67, 41)
# S 5: ship at (25111, -33428); waypoint (-67, 36)
# E 1: ship at (25111, -33428); waypoint (-66, 36)
# N 4: ship at (25111, -33428); waypoint (-66, 40)
# E 2: ship at (25111, -33428); waypoint (-64, 40)
# F 67: ship at (20823, -30748); waypoint (-64, 40)
# R 90: ship at (20823, -30748); waypoint (40, 64)
# E 2: ship at (20823, -30748); waypoint (42, 64)
# L 90: ship at (20823, -30748); waypoint (-64, 42)
# W 5: ship at (20823, -30748); waypoint (-69, 42)
# F 32: ship at (18615, -29404); waypoint (-69, 42)
# W 1: ship at (18615, -29404); waypoint (-70, 42)
# S 2: ship at (18615, -29404); waypoint (-70, 40)
# L 90: ship at (18615, -29404); waypoint (-40, -70)
# S 4: ship at (18615, -29404); waypoint (-40, -74)
# W 4: ship at (18615, -29404); waypoint (-44, -74)
# N 1: ship at (18615, -29404); waypoint (-44, -73)
# F 74: ship at (15359, -34806); waypoint (-44, -73)
# W 3: ship at (15359, -34806); waypoint (-47, -73)
# R 90: ship at (15359, -34806); waypoint (-73, 47)
# F 24: ship at (13607, -33678); waypoint (-73, 47)
# N 5: ship at (13607, -33678); waypoint (-73, 52)
# R 90: ship at (13607, -33678); waypoint (52, 73)
# F 74: ship at (17455, -28276); waypoint (52, 73)
# E 5: ship at (17455, -28276); waypoint (57, 73)
# L 90: ship at (17455, -28276); waypoint (-73, 57)
# W 4: ship at (17455, -28276); waypoint (-77, 57)
# R 180: ship at (17455, -28276); waypoint (77, -57)
# F 51: ship at (21382, -31183); waypoint (77, -57)
# W 2: ship at (21382, -31183); waypoint (75, -57)
# L 180: ship at (21382, -31183); waypoint (-75, 57)
# F 36: ship at (18682, -29131); waypoint (-75, 57)
# E 5: ship at (18682, -29131); waypoint (-70, 57)
# E 5: ship at (18682, -29131); waypoint (-65, 57)
# N 4: ship at (18682, -29131); waypoint (-65, 61)
# F 53: ship at (15237, -25898); waypoint (-65, 61)
# S 2: ship at (15237, -25898); waypoint (-65, 59)
# F 56: ship at (11597, -22594); waypoint (-65, 59)
# S 5: ship at (11597, -22594); waypoint (-65, 54)
# S 2: ship at (11597, -22594); waypoint (-65, 52)
# F 31: ship at (9582, -20982); waypoint (-65, 52)
# W 5: ship at (9582, -20982); waypoint (-70, 52)
# N 5: ship at (9582, -20982); waypoint (-70, 57)
# L 90: ship at (9582, -20982); waypoint (-57, -70)
# S 1: ship at (9582, -20982); waypoint (-57, -71)
# E 2: ship at (9582, -20982); waypoint (-55, -71)
# L 90: ship at (9582, -20982); waypoint (71, -55)
# N 2: ship at (9582, -20982); waypoint (71, -53)
# W 4: ship at (9582, -20982); waypoint (67, -53)
# F 5: ship at (9917, -21247); waypoint (67, -53)
# L 90: ship at (9917, -21247); waypoint (53, 67)
# S 2: ship at (9917, -21247); waypoint (53, 65)
# E 5: ship at (9917, -21247); waypoint (58, 65)
# F 62: ship at (13513, -17217); waypoint (58, 65)
# L 90: ship at (13513, -17217); waypoint (-65, 58)
# E 3: ship at (13513, -17217); waypoint (-62, 58)
# L 90: ship at (13513, -17217); waypoint (-58, -62)
# F 41: ship at (11135, -19759); waypoint (-58, -62)
# E 5: ship at (11135, -19759); waypoint (-53, -62)
# F 32: ship at (9439, -21743); waypoint (-53, -62)
# R 90: ship at (9439, -21743); waypoint (-62, 53)
# E 4: ship at (9439, -21743); waypoint (-58, 53)
# R 90: ship at (9439, -21743); waypoint (53, 58)
# N 1: ship at (9439, -21743); waypoint (53, 59)
# L 90: ship at (9439, -21743); waypoint (-59, 53)
# N 5: ship at (9439, -21743); waypoint (-59, 58)
# E 5: ship at (9439, -21743); waypoint (-54, 58)
# R 180: ship at (9439, -21743); waypoint (54, -58)
# E 1: ship at (9439, -21743); waypoint (55, -58)
# N 3: ship at (9439, -21743); waypoint (55, -55)
# R 90: ship at (9439, -21743); waypoint (-55, -55)
# W 4: ship at (9439, -21743); waypoint (-59, -55)
# F 86: ship at (4365, -26473); waypoint (-59, -55)
# F 8: ship at (3893, -26913); waypoint (-59, -55)
# S 1: ship at (3893, -26913); waypoint (-59, -56)
# R 90: ship at (3893, -26913); waypoint (-56, 59)
# N 4: ship at (3893, -26913); waypoint (-56, 63)
# L 90: ship at (3893, -26913); waypoint (-63, -56)
# N 4: ship at (3893, -26913); waypoint (-63, -52)
# W 3: ship at (3893, -26913); waypoint (-66, -52)
# F 39: ship at (1319, -28941); waypoint (-66, -52)
# R 90: ship at (1319, -28941); waypoint (-52, 66)
# S 4: ship at (1319, -28941); waypoint (-52, 62)
# E 2: ship at (1319, -28941); waypoint (-50, 62)
# F 59: ship at (-1631, -25283); waypoint (-50, 62)
# E 4: ship at (-1631, -25283); waypoint (-46, 62)
# N 1: ship at (-1631, -25283); waypoint (-46, 63)
# F 72: ship at (-4943, -20747); waypoint (-46, 63)
# E 1: ship at (-4943, -20747); waypoint (-45, 63)
# N 2: ship at (-4943, -20747); waypoint (-45, 65)
# E 4: ship at (-4943, -20747); waypoint (-41, 65)
# F 93: ship at (-8756, -14702); waypoint (-41, 65)
# S 2: ship at (-8756, -14702); waypoint (-41, 63)
# F 10: ship at (-9166, -14072); waypoint (-41, 63)
# R 180: ship at (-9166, -14072); waypoint (41, -63)
# F 74: ship at (-6132, -18734); waypoint (41, -63)
# S 1: ship at (-6132, -18734); waypoint (41, -64)
# S 1: ship at (-6132, -18734); waypoint (41, -65)
# F 67: ship at (-3385, -23089); waypoint (41, -65)
# R 90: ship at (-3385, -23089); waypoint (-65, -41)
# E 5: ship at (-3385, -23089); waypoint (-60, -41)
# F 66: ship at (-7345, -25795); waypoint (-60, -41)
# L 90: ship at (-7345, -25795); waypoint (41, -60)
# F 27: ship at (-6238, -27415); waypoint (41, -60)
# S 2: ship at (-6238, -27415); waypoint (41, -62)
# R 270: ship at (-6238, -27415); waypoint (62, 41)
# F 11: ship at (-5556, -26964); waypoint (62, 41)
# E 4: ship at (-5556, -26964); waypoint (66, 41)
# N 3: ship at (-5556, -26964); waypoint (66, 44)
# F 32: ship at (-3444, -25556); waypoint (66, 44)
# L 180: ship at (-3444, -25556); waypoint (-66, -44)
# S 4: ship at (-3444, -25556); waypoint (-66, -48)
# F 92: ship at (-9516, -29972); waypoint (-66, -48)
# L 90: ship at (-9516, -29972); waypoint (48, -66)
# N 1: ship at (-9516, -29972); waypoint (48, -65)
# E 3: ship at (-9516, -29972); waypoint (51, -65)
# R 180: ship at (-9516, -29972); waypoint (-51, 65)
# F 9: ship at (-9975, -29387); waypoint (-51, 65)
# R 90: ship at (-9975, -29387); waypoint (65, 51)
# F 31: ship at (-7960, -27806); waypoint (65, 51)
# E 5: ship at (-7960, -27806); waypoint (70, 51)
# L 90: ship at (-7960, -27806); waypoint (-51, 70)
# N 2: ship at (-7960, -27806); waypoint (-51, 72)
# F 13: ship at (-8623, -26870); waypoint (-51, 72)
# E 2: ship at (-8623, -26870); waypoint (-49, 72)
# L 90: ship at (-8623, -26870); waypoint (-72, -49)
# F 52: ship at (-12367, -29418); waypoint (-72, -49)
# W 3: ship at (-12367, -29418); waypoint (-75, -49)
# R 180: ship at (-12367, -29418); waypoint (75, 49)
# E 3: ship at (-12367, -29418); waypoint (78, 49)
# S 3: ship at (-12367, -29418); waypoint (78, 46)
# R 90: ship at (-12367, -29418); waypoint (46, -78)
# F 67: ship at (-9285, -34644); waypoint (46, -78)
# N 1: ship at (-9285, -34644); waypoint (46, -77)
# F 75: ship at (-5835, -40419); waypoint (46, -77)
# L 90: ship at (-5835, -40419); waypoint (77, 46)
# W 5: ship at (-5835, -40419); waypoint (72, 46)
# F 3: ship at (-5619, -40281); waypoint (72, 46)
# W 3: ship at (-5619, -40281); waypoint (69, 46)
# R 90: ship at (-5619, -40281); waypoint (46, -69)
# F 76: ship at (-2123, -45525); waypoint (46, -69)
# L 90: ship at (-2123, -45525); waypoint (69, 46)
# S 4: ship at (-2123, -45525); waypoint (69, 42)
# E 2: ship at (-2123, -45525); waypoint (71, 42)
# L 90: ship at (-2123, -45525); waypoint (-42, 71)
# W 2: ship at (-2123, -45525); waypoint (-44, 71)
# L 90: ship at (-2123, -45525); waypoint (-71, -44)
# R 90: ship at (-2123, -45525); waypoint (-44, 71)
# N 1: ship at (-2123, -45525); waypoint (-44, 72)
# F 77: ship at (-5511, -39981); waypoint (-44, 72)
# E 2: ship at (-5511, -39981); waypoint (-42, 72)
# L 180: ship at (-5511, -39981); waypoint (42, -72)
# E 4: ship at (-5511, -39981); waypoint (46, -72)
# L 90: ship at (-5511, -39981); waypoint (72, 46)
# F 65: ship at (-831, -36991); waypoint (72, 46)
# N 3: ship at (-831, -36991); waypoint (72, 49)
# L 180: ship at (-831, -36991); waypoint (-72, -49)
# F 1: ship at (-903, -37040); waypoint (-72, -49)
# W 2: ship at (-903, -37040); waypoint (-74, -49)
# N 5: ship at (-903, -37040); waypoint (-74, -44)
# F 97: ship at (-8081, -41308); waypoint (-74, -44)
# S 1: ship at (-8081, -41308); waypoint (-74, -45)
# W 2: ship at (-8081, -41308); waypoint (-76, -45)
# L 90: ship at (-8081, -41308); waypoint (45, -76)
# F 81: ship at (-4436, -47464); waypoint (45, -76)
# R 90: ship at (-4436, -47464); waypoint (-76, -45)
# S 4: ship at (-4436, -47464); waypoint (-76, -49)
# F 85: ship at (-10896, -51629); waypoint (-76, -49)
# R 180: ship at (-10896, -51629); waypoint (76, 49)
# F 45: ship at (-7476, -49424); waypoint (76, 49)
# W 3: ship at (-7476, -49424); waypoint (73, 49)
# N 2: ship at (-7476, -49424); waypoint (73, 51)
# N 5: ship at (-7476, -49424); waypoint (73, 56)
# W 4: ship at (-7476, -49424); waypoint (69, 56)
# R 90: ship at (-7476, -49424); waypoint (56, -69)
# N 4: ship at (-7476, -49424); waypoint (56, -65)
# E 3: ship at (-7476, -49424); waypoint (59, -65)
# N 5: ship at (-7476, -49424); waypoint (59, -60)
# W 4: ship at (-7476, -49424); waypoint (55, -60)
# F 29: ship at (-5881, -51164); waypoint (55, -60)
# E 5: ship at (-5881, -51164); waypoint (60, -60)
# R 180: ship at (-5881, -51164); waypoint (-60, 60)
# N 1: ship at (-5881, -51164); waypoint (-60, 61)
# R 180: ship at (-5881, -51164); waypoint (60, -61)
# F 17: ship at (-4861, -52201); waypoint (60, -61)
# E 3: ship at (-4861, -52201); waypoint (63, -61)
# R 90: ship at (-4861, -52201); waypoint (-61, -63)
# W 1: ship at (-4861, -52201); waypoint (-62, -63)
# F 62: ship at (-8705, -56107); waypoint (-62, -63)
# N 3: ship at (-8705, -56107); waypoint (-62, -60)
# F 87: ship at (-14099, -61327); waypoint (-62, -60)
# R 270: ship at (-14099, -61327); waypoint (60, -62)
# W 5: ship at (-14099, -61327); waypoint (55, -62)
# S 5: ship at (-14099, -61327); waypoint (55, -67)
# F 42: ship at (-11789, -64141); waypoint (55, -67)
# W 5: ship at (-11789, -64141); waypoint (50, -67)
# F 72: ship at (-8189, -68965); waypoint (50, -67)
# R 90: ship at (-8189, -68965); waypoint (-67, -50)
# E 3: ship at (-8189, -68965); waypoint (-64, -50)
# F 11: ship at (-8893, -69515); waypoint (-64, -50)
# R 90: ship at (-8893, -69515); waypoint (-50, 64)
# F 14: ship at (-9593, -68619); waypoint (-50, 64)
# S 3: ship at (-9593, -68619); waypoint (-50, 61)
# R 90: ship at (-9593, -68619); waypoint (61, 50)
# N 4: ship at (-9593, -68619); waypoint (61, 54)
# E 3: ship at (-9593, -68619); waypoint (64, 54)
# R 90: ship at (-9593, -68619); waypoint (54, -64)
# W 5: ship at (-9593, -68619); waypoint (49, -64)
# S 4: ship at (-9593, -68619); waypoint (49, -68)
# E 5: ship at (-9593, -68619); waypoint (54, -68)
# R 270: ship at (-9593, -68619); waypoint (68, 54)
# F 35: ship at (-7213, -66729); waypoint (68, 54)
# E 3: ship at (-7213, -66729); waypoint (71, 54)
# W 3: ship at (-7213, -66729); waypoint (68, 54)
# N 1: ship at (-7213, -66729); waypoint (68, 55)
# R 90: ship at (-7213, -66729); waypoint (55, -68)
# S 1: ship at (-7213, -66729); waypoint (55, -69)
# W 3: ship at (-7213, -66729); waypoint (52, -69)
# R 180: ship at (-7213, -66729); waypoint (-52, 69)
# F 80: ship at (-11373, -61209); waypoint (-52, 69)
# E 2: ship at (-11373, -61209); waypoint (-50, 69)
# F 24: ship at (-12573, -59553); waypoint (-50, 69)
# E 1: ship at (-12573, -59553); waypoint (-49, 69)
# R 90: ship at (-12573, -59553); waypoint (69, 49)
# F 23: ship at (-10986, -58426); waypoint (69, 49)
# S 3: ship at (-10986, -58426); waypoint (69, 46)
# L 90: ship at (-10986, -58426); waypoint (-46, 69)
# W 4: ship at (-10986, -58426); waypoint (-50, 69)
# F 37: ship at (-12836, -55873); waypoint (-50, 69)
# L 90: ship at (-12836, -55873); waypoint (-69, -50)
# F 55: ship at (-16631, -58623); waypoint (-69, -50)
# S 3: ship at (-16631, -58623); waypoint (-69, -53)
# N 4: ship at (-16631, -58623); waypoint (-69, -49)
# N 5: ship at (-16631, -58623); waypoint (-69, -44)
# L 90: ship at (-16631, -58623); waypoint (44, -69)
# N 1: ship at (-16631, -58623); waypoint (44, -68)
# L 90: ship at (-16631, -58623); waypoint (68, 44)
# F 99: ship at (-9899, -54267); waypoint (68, 44)
# R 90: ship at (-9899, -54267); waypoint (44, -68)
# N 4: ship at (-9899, -54267); waypoint (44, -64)
# E 1: ship at (-9899, -54267); waypoint (45, -64)
# R 90: ship at (-9899, -54267); waypoint (-64, -45)
# F 21: ship at (-11243, -55212); waypoint (-64, -45)
# N 4: ship at (-11243, -55212); waypoint (-64, -41)
# L 180: ship at (-11243, -55212); waypoint (64, 41)
# F 50: ship at (-8043, -53162); waypoint (64, 41)
# S 4: ship at (-8043, -53162); waypoint (64, 37)
# W 2: ship at (-8043, -53162); waypoint (62, 37)
# F 43: ship at (-5377, -51571); waypoint (62, 37)
# R 180: ship at (-5377, -51571); waypoint (-62, -37)
# F 7: ship at (-5811, -51830); waypoint (-62, -37)
# S 4: ship at (-5811, -51830); waypoint (-62, -41)
# W 1: ship at (-5811, -51830); waypoint (-63, -41)
# E 1: ship at (-5811, -51830); waypoint (-62, -41)
# N 4: ship at (-5811, -51830); waypoint (-62, -37)
# E 3: ship at (-5811, -51830); waypoint (-59, -37)
# R 180: ship at (-5811, -51830); waypoint (59, 37)
# F 3: ship at (-5634, -51719); waypoint (59, 37)
# S 1: ship at (-5634, -51719); waypoint (59, 36)
# F 48: ship at (-2802, -49991); waypoint (59, 36)
# L 180: ship at (-2802, -49991); waypoint (-59, -36)
# F 97: ship at (-8525, -53483); waypoint (-59, -36)
# R 90: ship at (-8525, -53483); waypoint (-36, 59)
# F 46: ship at (-10181, -50769); waypoint (-36, 59)
# W 2: ship at (-10181, -50769); waypoint (-38, 59)
# F 3: ship at (-10295, -50592); waypoint (-38, 59)
# W 4: ship at (-10295, -50592); waypoint (-42, 59)
# N 1: ship at (-10295, -50592); waypoint (-42, 60)
# R 180: ship at (-10295, -50592); waypoint (42, -60)
# N 5: ship at (-10295, -50592); waypoint (42, -55)
# E 4: ship at (-10295, -50592); waypoint (46, -55)
# R 180: ship at (-10295, -50592); waypoint (-46, 55)
# S 5: ship at (-10295, -50592); waypoint (-46, 50)
# F 99: ship at (-14849, -45642); waypoint (-46, 50)
# N 5: ship at (-14849, -45642); waypoint (-46, 55)
# E 2: ship at (-14849, -45642); waypoint (-44, 55)
# R 90: ship at (-14849, -45642); waypoint (55, 44)
# S 2: ship at (-14849, -45642); waypoint (55, 42)
# W 5: ship at (-14849, -45642); waypoint (50, 42)
# N 5: ship at (-14849, -45642); waypoint (50, 47)
# R 90: ship at (-14849, -45642); waypoint (47, -50)
# F 26: ship at (-13627, -46942); waypoint (47, -50)
# W 3: ship at (-13627, -46942); waypoint (44, -50)
# N 3: ship at (-13627, -46942); waypoint (44, -47)
# F 25: ship at (-12527, -48117); waypoint (44, -47)
# E 4: ship at (-12527, -48117); waypoint (48, -47)
# S 2: ship at (-12527, -48117); waypoint (48, -49)
# F 62: ship at (-9551, -51155); waypoint (48, -49)
# S 5: ship at (-9551, -51155); waypoint (48, -54)
# F 54: ship at (-6959, -54071); waypoint (48, -54)
# R 90: ship at (-6959, -54071); waypoint (-54, -48)
# F 45: ship at (-9389, -56231); waypoint (-54, -48)
# S 4: ship at (-9389, -56231); waypoint (-54, -52)
# F 97: ship at (-14627, -61275); waypoint (-54, -52)
# R 90: ship at (-14627, -61275); waypoint (-52, 54)
# W 1: ship at (-14627, -61275); waypoint (-53, 54)
# F 68: ship at (-18231, -57603); waypoint (-53, 54)
# N 3: ship at (-18231, -57603); waypoint (-53, 57)
# R 90: ship at (-18231, -57603); waypoint (57, 53)
# F 76: ship at (-13899, -53575); waypoint (57, 53)
# R 90: ship at (-13899, -53575); waypoint (53, -57)
# N 2: ship at (-13899, -53575); waypoint (53, -55)
# R 180: ship at (-13899, -53575); waypoint (-53, 55)
# N 2: ship at (-13899, -53575); waypoint (-53, 57)
# F 42: ship at (-16125, -51181); waypoint (-53, 57)
# L 180: ship at (-16125, -51181); waypoint (53, -57)
# E 5: ship at (-16125, -51181); waypoint (58, -57)
# L 90: ship at (-16125, -51181); waypoint (57, 58)
# W 4: ship at (-16125, -51181); waypoint (53, 58)
# N 4: ship at (-16125, -51181); waypoint (53, 62)
# F 39: ship at (-14058, -48763); waypoint (53, 62)
# N 4: ship at (-14058, -48763); waypoint (53, 66)
# R 180: ship at (-14058, -48763); waypoint (-53, -66)
# W 2: ship at (-14058, -48763); waypoint (-55, -66)
# N 1: ship at (-14058, -48763); waypoint (-55, -65)
# F 19: ship at (-15103, -49998); waypoint (-55, -65)
# R 90: ship at (-15103, -49998); waypoint (-65, 55)
# W 5: ship at (-15103, -49998); waypoint (-70, 55)
# L 90: ship at (-15103, -49998); waypoint (-55, -70)
# N 3: ship at (-15103, -49998); waypoint (-55, -67)
# L 90: ship at (-15103, -49998); waypoint (67, -55)
# F 24: ship at (-13495, -51318); waypoint (67, -55)
# S 2: ship at (-13495, -51318); waypoint (67, -57)
# R 180: ship at (-13495, -51318); waypoint (-67, 57)
# N 5: ship at (-13495, -51318); waypoint (-67, 62)
# E 4: ship at (-13495, -51318); waypoint (-63, 62)
# F 92: ship at (-19291, -45614); waypoint (-63, 62)
# N 2: ship at (-19291, -45614); waypoint (-63, 64)
# R 90: ship at (-19291, -45614); waypoint (64, 63)
# F 73: ship at (-14619, -41015); waypoint (64, 63)
# W 3: ship at (-14619, -41015); waypoint (61, 63)
# S 2: ship at (-14619, -41015); waypoint (61, 61)
# L 180: ship at (-14619, -41015); waypoint (-61, -61)
# F 53: ship at (-17852, -44248); waypoint (-61, -61)
# S 5: ship at (-17852, -44248); waypoint (-61, -66)
# W 5: ship at (-17852, -44248); waypoint (-66, -66)
# W 4: ship at (-17852, -44248); waypoint (-70, -66)
# L 90: ship at (-17852, -44248); waypoint (66, -70)
# S 3: ship at (-17852, -44248); waypoint (66, -73)
# L 90: ship at (-17852, -44248); waypoint (73, 66)
# F 49: ship at (-14275, -41014); waypoint (73, 66)
# R 90: ship at (-14275, -41014); waypoint (66, -73)
# W 4: ship at (-14275, -41014); waypoint (62, -73)
# N 1: ship at (-14275, -41014); waypoint (62, -72)
# R 90: ship at (-14275, -41014); waypoint (-72, -62)
# N 1: ship at (-14275, -41014); waypoint (-72, -61)
# E 1: ship at (-14275, -41014); waypoint (-71, -61)
# R 270: ship at (-14275, -41014); waypoint (61, -71)
# E 1: ship at (-14275, -41014); waypoint (62, -71)
# F 62: ship at (-10431, -45416); waypoint (62, -71)
# N 1: ship at (-10431, -45416); waypoint (62, -70)
# E 5: ship at (-10431, -45416); waypoint (67, -70)
# R 90: ship at (-10431, -45416); waypoint (-70, -67)
# F 59: ship at (-14561, -49369); waypoint (-70, -67)
# F 56: ship at (-18481, -53121); waypoint (-70, -67)
# R 180: ship at (-18481, -53121); waypoint (70, 67)
# F 25: ship at (-16731, -51446); waypoint (70, 67)
# L 180: ship at (-16731, -51446); waypoint (-70, -67)
# W 3: ship at (-16731, -51446); waypoint (-73, -67)
# L 90: ship at (-16731, -51446); waypoint (67, -73)
# N 3: ship at (-16731, -51446); waypoint (67, -70)
# E 4: ship at (-16731, -51446); waypoint (71, -70)
# S 2: ship at (-16731, -51446); waypoint (71, -72)
# S 3: ship at (-16731, -51446); waypoint (71, -75)
# E 4: ship at (-16731, -51446); waypoint (75, -75)
# L 90: ship at (-16731, -51446); waypoint (75, 75)
# E 4: ship at (-16731, -51446); waypoint (79, 75)
# N 5: ship at (-16731, -51446); waypoint (79, 80)
# F 81: ship at (-10332, -44966); waypoint (79, 80)
# S 4: ship at (-10332, -44966); waypoint (79, 76)
# F 54: ship at (-6066, -40862); waypoint (79, 76)
# S 2: ship at (-6066, -40862); waypoint (79, 74)
# R 90: ship at (-6066, -40862); waypoint (74, -79)
# S 2: ship at (-6066, -40862); waypoint (74, -81)
# F 4: ship at (-5770, -41186); waypoint (74, -81)
# W 4: ship at (-5770, -41186); waypoint (70, -81)
# N 1: ship at (-5770, -41186); waypoint (70, -80)
# F 100: ship at (1230, -49186); waypoint (70, -80)
# L 90: ship at (1230, -49186); waypoint (80, 70)
# S 5: ship at (1230, -49186); waypoint (80, 65)
# L 180: ship at (1230, -49186); waypoint (-80, -65)
# F 59: ship at (-3490, -53021); waypoint (-80, -65)
# L 90: ship at (-3490, -53021); waypoint (65, -80)
# F 56: ship at (150, -57501); waypoint (65, -80)
# S 1: ship at (150, -57501); waypoint (65, -81)
# F 5: ship at (475, -57906); waypoint (65, -81)
# F 79: ship at (5610, -64305); waypoint (65, -81)
# R 90: ship at (5610, -64305); waypoint (-81, -65)
# N 5: ship at (5610, -64305); waypoint (-81, -60)
# W 4: ship at (5610, -64305); waypoint (-85, -60)
# N 5: ship at (5610, -64305); waypoint (-85, -55)
# W 4: ship at (5610, -64305); waypoint (-89, -55)
# N 3: ship at (5610, -64305); waypoint (-89, -52)
# R 180: ship at (5610, -64305); waypoint (89, 52)
# W 5: ship at (5610, -64305); waypoint (84, 52)
# R 90: ship at (5610, -64305); waypoint (52, -84)
# S 5: ship at (5610, -64305); waypoint (52, -89)
# F 92: ship at (10394, -72493); waypoint (52, -89)
# S 4: ship at (10394, -72493); waypoint (52, -93)
# E 4: ship at (10394, -72493); waypoint (56, -93)
# F 17: ship at (11346, -74074); waypoint (56, -93)
# N 2: ship at (11346, -74074); waypoint (56, -91)
# L 90: ship at (11346, -74074); waypoint (91, 56)
# S 2: ship at (11346, -74074); waypoint (91, 54)
# L 90: ship at (11346, -74074); waypoint (-54, 91)
# F 62: ship at (7998, -68432); waypoint (-54, 91)
# N 1: ship at (7998, -68432); waypoint (-54, 92)
# F 2: ship at (7890, -68248); waypoint (-54, 92)
# W 2: ship at (7890, -68248); waypoint (-56, 92)
# N 4: ship at (7890, -68248); waypoint (-56, 96)
# F 40: ship at (5650, -64408); waypoint (-56, 96)
# R 90: ship at (5650, -64408); waypoint (96, 56)
# S 2: ship at (5650, -64408); waypoint (96, 54)
# L 180: ship at (5650, -64408); waypoint (-96, -54)
# E 5: ship at (5650, -64408); waypoint (-91, -54)
# S 4: ship at (5650, -64408); waypoint (-91, -58)
# F 100: ship at (-3450, -70208); waypoint (-91, -58)
# W 2: ship at (-3450, -70208); waypoint (-93, -58)
# F 27: ship at (-5961, -71774); waypoint (-93, -58)
# W 5: ship at (-5961, -71774); waypoint (-98, -58)
# R 90: ship at (-5961, -71774); waypoint (-58, 98)
# S 1: ship at (-5961, -71774); waypoint (-58, 97)
# L 90: ship at (-5961, -71774); waypoint (-97, -58)
# E 5: ship at (-5961, -71774); waypoint (-92, -58)
# R 90: ship at (-5961, -71774); waypoint (-58, 92)
# W 5: ship at (-5961, -71774); waypoint (-63, 92)
# R 90: ship at (-5961, -71774); waypoint (92, 63)
# R 180: ship at (-5961, -71774); waypoint (-92, -63)
# S 3: ship at (-5961, -71774); waypoint (-92, -66)
# E 2: ship at (-5961, -71774); waypoint (-90, -66)
# F 75: ship at (-12711, -76724); waypoint (-90, -66)
# N 5: ship at (-12711, -76724); waypoint (-90, -61)
# R 180: ship at (-12711, -76724); waypoint (90, 61)
# F 8: ship at (-11991, -76236); waypoint (90, 61)
# S 5: ship at (-11991, -76236); waypoint (90, 56)
# F 64: ship at (-6231, -72652); waypoint (90, 56)

# %%
# Part 2 solution
nav.ship.manhattan()
# Out:
# 78883
